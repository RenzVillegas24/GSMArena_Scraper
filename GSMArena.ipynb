# %%
import requests as rq
import csv
import bs4
import datetime
from urllib.parse import quote
import pandas as pd
import re

# %%
google_cache = r"http://webcache.googleusercontent.com/search?q=cache:"
device_list = r"m.gsmarena.com"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
    'Referer': 'https://www.google.com/'
}

#get the xml file from the sitemap
doc = bs4.BeautifulSoup(
    rq.get(f"{google_cache}{device_list}/makers.php3", headers=headers).text, 
    "html.parser")

print(doc)


brands_dict = {}
for brand in doc.select("div#list-brands a"):
    brands_dict[brand.text] = brand.attrs["href"]

    doc = bs4.BeautifulSoup(
        rq.get(f"{google_cache}{device_list}/{quote(brand.attrs['href'])}", headers=headers).text, 
        "html.parser")

    phones_dict = {}

    last_page = int(doc.select_one("div#nav-review-page div.nav-container div.nav-current span").text.split("of")[1])


    print(last_page, brand.text)


'''
    for page in range(1, last_page):
        doc = bs4.BeautifulSoup(
            rq.get(f"{google_cache}{device_list}/{brand.attrs["href"]}?sPage={page}").text, 
            "html.parser")

        for phone in doc.select("div#list-brands div.general-menu ul li a"):
            spec = phone.attrs["href"]

    
            match = re.search(r"(.*?)-(\d+).php", phone.attrs["href"])

            if match:
                brand_name = match.group(1)
                brand_id = match.group(2)

                doc = bs4.BeautifulSoup(
                    rq.get(f"{google_cache}{device_list}/{quote(brand_name.lower().replace(" ", "_"))}-phones-f-{brand_id}-0-p{page+1}.php").text, 
                    "html.parser")
                
                for phone in doc.select("div#list-brands div.makers ul li"):
                '''

pass

# browse through the brands
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html><head><meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="initial-scale=1" name="viewport"/><title>http://webcache.googleusercontent.com/search?q=cache:m.gsmarena.com/makers.php3</title></head>
# <body onload="e=document.getElementById('captcha');if(e){e.focus();} if(solveSimpleChallenge) {solveSimpleChallenge(,);}" style="font-family: arial, sans-serif; background-color: #fff; color: #000; padding:20px; font-size:18px; overscroll-behavior:contain;">
# <div style="max-width:400px;">
# <hr noshade="" size="1" style="color:#ccc; background-color:#ccc;"/><br/>
# <form action="index" id="captcha-form" method="post">
# <noscript>
# <div style="font-size:13px;">
#   In order to continue, please enable javascript on your web browser.
# </div>
# </noscript>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# ...

# %%
# for devices in locs:
device = locs[66]

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
    'Referer': 'https://www.google.com/'
}

# get the device page
response = rq.get(f"{google_cache}{quote(device + '&d=detailed_specs')}", headers=headers)
doc = bs4.BeautifulSoup(response.text, 'html.parser')

print(device)

# %%
# get all the td in which the td does not have colspan=2
# get the tr not the td 

# use pandas to get the table ".canvas table"
table = doc.select_one(".canvas table")
df = pd.read_html(str(table))[0]

# convert the table to a dataframe

df
