# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# Sample dataset of phones with specifications
data = {
    'Phone': [
        'iPhone 11',
        'iPhone 11 Pro',
        'iPhone 11 Pro Max',
        'iPhone 12',
        'iPhone 12 Mini',
        'iPhone 12 Pro',
        'iPhone 12 Pro Max',
        'iPhone 13',
        'iPhone 13 Mini',
        'iPhone 13 Pro',
        'vivo Y36',
        'vivo Y36 5G',
        'vivo Y3 Standard',
        'vivo Y3s',
        'vivo Y3t',
        'vivo Y3t 5G',
        'vivo Y3t Pro',
        'vivo Y3t Pro 5G',
        'vivo Y3t Pro Max',
        'vivo Y3t Pro Max 5G',
    ],
    'Specifications': [
        '//www.lazada.com.ph/products/apple-iphone-11-late-2020-i1540574597.html|Apple|194g, 8.3mm thickness|iOS|iPhone 11|Released 2019, September 20|Wired, PD2.0, 50% in 30 min (advertised)\nWireless (Qi)|Li-Ion 3110 mAh|IP68 dust/water resistant (up to 2m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by) - for China|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Scratch-resistant glass|Liquid Retina IPS LCD, 625 nits (typ)|2019|Available. Released 2019, September 20|12 MP, f/1.8, 26mm (wide), 1/2.55", 1.4m, dual pixel PDAF, OIS\n12 MP, f/2.4, 120, 13mm (ultrawide), 1/3.6"|Dual-LED dual-tone flash, HDR (photo/panorama)|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, stereo sound rec.|No|NVMe|Black, Green, Yellow, Purple, Red, White|A2221|$228.00 / C$378.88 / 211.00 / 289.00|1.09 W/kg (head)   1.18 W/kg (body)   |0.95 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Thunder)|Apple A13 Bionic (7 nm+)|Apple GPU (4-core graphics)|iOS 13, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\nNoise -94.2dB / Crosstalk -80.8dB|\n\nEndurance rating 94h\n\n|\nPhoto / Video|\nContrast ratio: 1505:1 (nominal)|Loudspeaker||\nAnTuTu: 419453 (v7)\nGeekBench: 13882 (v4.4)\nGFXBench: 60fps (ES 3.1 onscreen)|64GB/128GB/256GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-11-pro-i1715270221-s7407188449.html|Apple|188g, 8.1mm thickness|iOS|iPhone 11 Pro|Released 2019, September 20|Wired, PD2.0, 50% in 30 min (advertised)\nWireless (Qi)|Li-Ion 3046 mAh|IP68 dust/water resistant (up to 4m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by) - for China|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Scratch-resistant glass|Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)|2019|Available. Released 2019, September 20|Dual-LED dual-tone flash, HDR (photo/panorama)|12 MP, f/1.8, 26mm (wide), 1/2.55", 1.4m, dual pixel PDAF, OIS\n12 MP, f/2.0, 52mm (telephoto), 1/3.4", 1.0m, PDAF, OIS, 2x optical zoom\n12 MP, f/2.4, 120, 13mm (ultrawide), 1/3.6"|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, stereo sound rec.|No|NVMe|Matte Space Gray, Matte Silver, Matte Gold, Matte Midnight Green|A2215|$289.00 / C$421.37 / 262.56 / 317.00|1.18 W/kg (head)   1.16 W/kg (body)   |0.99 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Thunder)|Apple A13 Bionic (7 nm+)|Apple GPU (4-core graphics)|iOS 13, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\nNoise -94.2dB / Crosstalk -81.0dB|\n\nEndurance rating 86h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 460784 (v7)\nGeekBench: 13829 (v4.4)\nGFXBench: 57fps (ES 3.1 onscreen)|64GB/256GB/512GB storage, no card slot|',
        '//www.lazada.com.ph/products/11-promax-64gbbrandnew-i3431261377-s17589398132.html|Apple|226g, 8.1mm thickness|iOS|iPhone 11 Pro Max|Released 2019, September 20|Wired, PD2.0, 50% in 30 min (advertised)\nWireless (Qi)|Li-Ion 3969 mAh|IP68 dust/water resistant (up to 4m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by) - for China|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Scratch-resistant glass|Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)|2019|Available. Released 2019, September 20|Dual-LED dual-tone flash, HDR (photo/panorama)|12 MP, f/1.8, 26mm (wide), 1/2.55", 1.4m, dual pixel PDAF, OIS\n12 MP, f/2.0, 52mm (telephoto), 1/3.4", 1.0m, PDAF, OIS, 2x optical zoom\n12 MP, f/2.4, 120, 13mm (ultrawide), 1/3.6"|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, stereo sound rec.|No|NVMe|Matte Space Gray, Matte Silver, Matte Gold, Matte Midnight Green|A2218|$332.75 / C$470.06 / 308.49 / 375.00|1.16 W/kg (head)   1.17 W/kg (body)   |0.95 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x2.65 GHz Lightning + 4x1.8 GHz Thunder)|Apple A13 Bionic (7 nm+)|Apple GPU (4-core graphics)|iOS 13, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\nNoise -94.3dB / Crosstalk -81.5dB|\n\nEndurance rating 102h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 459713 (v7), 536883 (v8)\nGeekBench: 13870 (v4.4), 3503 (v5.1)\nGFXBench: 57fps (ES 3.1 onscreen)|64GB/256GB/512GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-12-i1515046971.html|Apple|164g, 7.4mm thickness|iOS|iPhone 12|Released 2020, October 23|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n7.5W wireless (Qi)|Li-Ion 2815 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by) - for China|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, HDR10, Dolby Vision, 625 nits (HBM), 1200 nits (peak)|2020|Available. Released 2020, October 23|12 MP, f/1.6, 26mm (wide), 1.4m, dual pixel PDAF, OIS\n12 MP, f/2.4, 13mm, 120 (ultrawide), 1/3.6"|Dual-LED dual-tone flash, HDR (photo/panorama)|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, Dolby Vision HDR (up to 30fps), stereo sound rec.|No|NVMe|Black, White, Red, Green, Blue, Purple|A2403|$248.42 / C$420.98 / 275.00 / 343.50 / 63,999|0.99 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x3.1 GHz Firestorm + 4x1.8 GHz Icestorm)|Apple A14 Bionic (5 nm)|Apple GPU (4-core graphics)|iOS 14.1, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 84h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 568674 (v8)\nGeekBench: 4067 (v5.1)\nGFXBench: 58fps (ES 3.1 onscreen)|64GB/128GB/256GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-12-mini-i1714190253-s8504869642.html|Apple|135g, 7.4mm thickness|iOS|iPhone 12 mini|Released 2020, November 13|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n7.5W wireless (Qi)|Li-Ion 2227 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, HDR10, Dolby Vision, 625 nits (HBM), 1200 nits (peak)|2020|Available. Released 2020, November 13|12 MP, f/1.6, 26mm (wide), 1.4m, dual pixel PDAF, OIS\n12 MP, f/2.4, 13mm, 120 (ultrawide), 1/3.6"|Dual-LED dual-tone flash, HDR (photo/panorama)|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, Dolby Vision HDR (up to 30fps), stereo sound rec.|No|NVMe|Black, White, Red, Green, Blue, Purple|A2399|$247.00 / C$372.85 / 259.00 / 299.99|0.99 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x3.1 GHz Firestorm + 4x1.8 GHz Icestorm)|Apple A14 Bionic (5 nm)|Apple GPU (4-core graphics)|iOS 14.1, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 69h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 589616 (v8)\nGeekBench: 4174 (v5.1)\nGFXBench: 60fps (ES 3.1 onscreen)|64GB/128GB/256GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-12-pro-i1713596899-s7403324885.html|Apple|189g, 7.4mm thickness|iOS|iPhone 12 Pro|Released 2020, October 23|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n7.5W wireless (Qi)|Li-Ion 2815 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by) - for China|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)|2020|Available. Released 2020, October 23|Dual-LED dual-tone flash, HDR (photo/panorama)|12 MP, f/1.6, 26mm (wide), 1.4m, dual pixel PDAF, OIS\n12 MP, f/2.0, 52mm (telephoto), 1/3.4", 1.0m, PDAF, OIS, 2x optical zoom\n12 MP, f/2.4, 13mm, 120 (ultrawide), 1/3.6"\nTOF 3D LiDAR scanner (depth)|4K@24/30/60fps, 1080p@30/60/120/240fps, 10bit HDR, Dolby Vision HDR (up to 60fps), stereo sound rec.|No|NVMe|Silver, Graphite, Gold, Pacific Blue|A2407|$385.90 / C$557.59 / 349.00 / 448.00|0.99 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x3.1 GHz Firestorm + 4x1.8 GHz Icestorm)|Apple A14 Bionic (5 nm)|Apple GPU (4-core graphics)|iOS 14.1, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 81h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 596244 (v8)\nGeekBench: 4056 (v5.1)\nGFXBench: 58fps (ES 3.1 onscreen)|128GB/256GB/512GB storage, no card slot|',
        '//www.lazada.com.ph/products/12-pro-max-128256gb-brand-new-100-original-i2567667208-s11946964583.html|Apple|228g, 7.4mm thickness|iOS|iPhone 12 Pro Max|Released 2020, November 13|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n7.5W wireless (Qi)|Li-Ion 3687 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by) - for China|Bluetooth|NFC|GPS, GLONASS, GALILEO, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)|2020|Available. Released 2020, November 13|Dual-LED dual-tone flash, HDR (photo/panorama)|12 MP, f/1.6, 26mm (wide), 1.7m, dual pixel PDAF, sensor-shift OIS\n12 MP, f/2.2, 65mm (telephoto), 1/3.4", 1.0m, PDAF, OIS, 2.5x optical zoom\n12 MP, f/2.4, 13mm, 120 (ultrawide), 1/3.6"\nTOF 3D LiDAR scanner (depth)|4K@24/30/60fps, 1080p@30/60/120/240fps, 10bit HDR, Dolby Vision HDR (up to 60fps), stereo sound rec.|No|NVMe|Silver, Graphite, Gold, Pacific Blue|A2411|$445.75 / C$624.00 / 415.99 / 484.00|0.99 W/kg (head)   0.99 W/kg (body)   |Hexa-core (2x3.1 GHz Firestorm + 4x1.8 GHz Icestorm)|Apple A14 Bionic (5 nm)|Apple GPU (4-core graphics)|iOS 14.1, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 95h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 638584 (v8)\nGeekBench: 4240 (v5.1)\nGFXBench: 55fps (ES 3.1 onscreen)|128GB/256GB/512GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-13-i2452737336.html|Apple|174g, 7.7mm thickness|iOS|iPhone 13|Released 2021, September 24|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n15W wireless (Qi2) - requires iOS 17.2 update|Li-Ion 3240 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)|2021|Available. Released 2021, September 24|12 MP, f/1.6, 26mm (wide), 1.7m, dual pixel PDAF, sensor-shift OIS\n12 MP, f/2.4, 120, 13mm (ultrawide)|Dual-LED dual-tone flash, HDR (photo/panorama)|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, Dolby Vision HDR (up to 60fps), stereo sound rec.|No|NVMe|Starlight, Midnight, Blue, Pink, Red, Green|A2633|$387.97 / C$612.00 / 369.00 / 505.69 / 52,999|1.18 W/kg (head)   1.19 W/kg (body)   |0.99 W/kg (head)   0.98 W/kg (body)   |Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)|Apple A15 Bionic (5 nm)|Apple GPU (4-core graphics)|iOS 15, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/25/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 89h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 775519 (v9)\nGeekBench: 4645 (v5.1)\nGFXBench: 59fps (ES 3.1 onscreen)|128GB/256GB/512GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-13-mini-i2453010273.html|Apple|141g, 7.7mm thickness|iOS|iPhone 13 mini|Released 2021, September 24|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n15W wireless (Qi2) - requires iOS 17.2 update|Li-Ion 2438 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, HDR10, Dolby Vision, 800 nits (HBM), 1200 nits (peak)|2021|Available. Released 2021, September 24|12 MP, f/1.6, 26mm (wide), 1.7m, dual pixel PDAF, sensor-shift OIS\n12 MP, f/2.4, 120, 13mm (ultrawide)|Dual-LED dual-tone flash, HDR (photo/panorama)|4K@24/30/60fps, 1080p@30/60/120/240fps, HDR, Dolby Vision HDR (up to 60fps), stereo sound rec.|No|NVMe|Starlight, Midnight, Blue, Pink, Red, Green|A2628|$419.75 / C$544.16 / 363.97 / 487.50|1.19 W/kg (head)   1.19 W/kg (body)   |0.97 W/kg (head)   0.98 W/kg (body)   |Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)|Apple A15 Bionic (5 nm)|Apple GPU (4-core graphics)|iOS 15, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/25/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 75h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 772512 (v9)\nGeekBench: 4681 (v5.1)\nGFXBench: 60fps (ES 3.1 onscreen)|128GB/256GB/512GB storage, no card slot|',
        '//www.lazada.com.ph/products/apple-iphone-13-pro-i2399793312-s15289809591.html|Apple|204g, 7.7mm thickness|iOS|iPhone 13 Pro|Released 2021, September 24|Wired, PD2.0, 50% in 30 min (advertised)\n15W wireless (MagSafe)\n15W wireless (Qi2) - requires iOS 17.2 update|Li-Ion 3095 mAh|IP68 dust/water resistant (up to 6m for 30 min)\nApple Pay (Visa, MasterCard, AMEX certified)|Nano-SIM and eSIM or Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS, QZSS|Radio|Lightning, USB 2.0|Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot|Ceramic Shield glass|Super Retina XDR OLED, 120Hz, HDR10, Dolby Vision, 1000 nits (HBM), 1200 nits (peak)|2021|Available. Released 2021, September 24|Dual-LED dual-tone flash, HDR (photo/panorama)|12 MP, f/1.5, 26mm (wide), 1/1.7", 1.9m, dual pixel PDAF, sensor-shift OIS\n12 MP, f/2.8, 77mm (telephoto), PDAF, 1/3.5", OIS, 3x optical zoom\n12 MP, f/1.8, 13mm, 120 (ultrawide), 1/3.5", PDAF\nTOF 3D LiDAR scanner (depth)|4K@24/30/60fps, 1080p@30/60/120/240fps, 10bit HDR, Dolby Vision HDR (up to 60fps), ProRes, Cinematic mode (1080p@30fps), stereo sound rec.|No|NVMe|Graphite, Gold, Silver, Sierra Blue, Alpine Green|A2638|$514.97 / C$724.99 / 445.49 / 597.07|1.20 W/kg (head)   1.19 W/kg (body)   |0.99 W/kg (head)   0.98 W/kg (body)   |Hexa-core (2x3.23 GHz Avalanche + 4x1.82 GHz Blizzard)|Apple A15 Bionic (5 nm)|Apple GPU (5-core graphics)|iOS 15, upgradable to iOS 17.3|HDR|12 MP, f/2.2, 23mm (wide), 1/3.6"\nSL 3D, (depth/biometrics sensor)|4K@24/25/30/60fps, 1080p@30/60/120fps, gyro-EIS|\n\nEndurance rating 85h\n\n|\nPhoto / Video|\nContrast ratio: Infinite (nominal)|Loudspeaker||\nAnTuTu: 794348 (v9)\nGeekBench: 4687 (v5.1)\nGFXBench: 60fps (ES 3.1 onscreen)|128GB/256GB/1TB storage, no card slot|',
        '//www.lazada.com.ph/products/newvivo-y36-mobile-phone-256gb-big-storage-8gb-ram-cellphone-44w-fastcharge-5000mah-bettery-smartphone-50mp-phone-camera-6nm-snapdragon-chip-gamingphone-i3933573304.html|vivo|202g, 8.1mm thickness|Android|Y36|Released 2023, May 27|44W wired, 30% in 15 min (advertised)\nReverse wired|5000 mAh|IP54, dust and splash resistant|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS, QZSS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band|IPS LCD, 90Hz, 650 nits (peak)|2023|Available. Released 2023, May 27|LED flash|50 MP, f/1.8, (wide), PDAF\n2 MP, f/2.4, (depth)\n2 MP, f/2.4, (macro)\n* the macro camera availability is market/region dependent|1080p@30fps|microSDXC (dedicated slot)|Meteor Black, Gold, Aqua Glitter|V2247|About 200 EUR|Octa-core (4x2.4 GHz Kryo 265 Gold & 4x1.9 GHz Kryo 265 Silver)|Qualcomm SM6225 Snapdragon 680 4G (6 nm)|Adreno 610|Android 13, Funtouch 13|16 MP, f/2.5, (wide)|1080p@30fps|64GB/128GB/256GB storage, microSDXC|',
       '//www.lazada.com.ph/products/newvivo-y36-5g-cellphone-8gb-ram-256gb-big-storage-mobiles-phone-240hz-gaming-touch-sampling-rate-90-hz-refresh-rate-gamingphone-44w-fastcharge-5000mah-all-day-battery-smartphone-android-13-vivo-phones-i4016125540.html|vivo|190g, 8.1mm thickness|Android|Y36 5G|Released 2023, June 13|44W wired, 30% in 15 min (advertised)\nReverse wired|5000 mAh|IP54, dust and splash resistant|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS, QZSS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band|IPS LCD, 90Hz, 650 nits (peak)|2023|Available. Released 2023, June 13|50 MP, f/1.8, (wide), PDAF\n2 MP, f/2.4, (depth)|LED flash|1080p@30fps|Unspecified|Crystal Green, Mystic Black|V2248|About 220 EUR|Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)|Mediatek Dimensity 6020 (7 nm)|Mali-G57 MC2|Android 13, Funtouch 13|16 MP, f/2.5, (wide)|1080p@30fps|256GB storage, Unspecified|',
       '//www.lazada.com.ph/products/original-vivo-y3-4128gb-global-rom-used-i3150242098.html|vivo|191.5g, 8.9mm thickness|Android|Y3 Standard|Released 2019, November|10W wired|5000 mAh|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, BDS|Radio|microUSB 2.0, OTG|Wi-Fi 802.11 b/g/n|IPS LCD|2019|Available. Released 2019, November|LED flash, HDR, panorama|13 MP, f/2.2, (wide), PDAF\n2 MP, f/2.4, (depth)|1080p@30fps|microSDXC (dedicated slot)|eMMC 5.1|Ink blue, Jade Red|V1930A|About 130 EUR|Octa-core (4x1.95 GHz Cortex-A53 & 4x1.45 GHz Cortex A53)|Qualcomm SDM439 Snapdragon 439 (12 nm)|Adreno 505|Android 9.0 (Pie), Funtouch 9.1|8 MP, f/1.8|1080p@30fps|64GB storage, microSDXC|',
       '//www.lazada.com.ph/products/original-android-phone-for-vivo-y51-2gb16gb-2350mah-i2408408660.html|vivo|188g, 8.4mm thickness|Android|Y51 (2020, December)|Released 2020, December 07|18W wired, 70% in 67 min (advertised)|5000 mAh|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|IPS LCD|2020|Available. Released 2020, December 07|LED flash, HDR, panorama|48 MP, f/1.8, (wide), 1/2.0", 0.8m, PDAF\n8 MP, f/2.2, 120, (ultrawide), 1/4.0", 1.12m\n2 MP, f/2.4, (macro)|4K@30fps, 1080p@30fps, gyro-EIS|microSDXC (dedicated slot)|Titanium Sapphire, Crystal Symphony|V2030|About 210 EUR|Octa-core (4x2.0 GHz Kryo 260 Gold & 4x1.8 GHz Kryo 260 Silver)|Qualcomm SDM665 Snapdragon 665 (11 nm)|Adreno 610|Android 11, Funtouch 11|HDR|16 MP, f/2.0, (wide), 1/3.06" 1.0m|1080p@30fps|128GB storage, microSDXC|',
       '//www.lazada.com.ph/products/original-android-phone-for-vivo-y51-2gb16gb-2350mah-i2408408660.html|vivo|186.7g, 8.7mm thickness|Android|Y51 (2020, September)|Released 2020, September 19|18W wired|4500 mAh|Hybrid Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|Super AMOLED|2020|Available. Released 2020, September 19|LED flash, HDR, panorama|48 MP, f/1.8, (wide), 1/2.0", 0.8m, PDAF\n8 MP, f/2.2, 120, (ultrawide), 1/4.0", 1.12m\n2 MP, f/2.4, (macro)\n2 MP, f/2.4, (depth)|1080p@30fps, gyro-EIS|microSDXC (uses shared SIM slot)|Mystic Black, Jazzy Blue, Dreamy White|Unknown|About 180 EUR|Octa-core (4x2.0 GHz Kryo 260 Gold & 4x1.8 GHz Kryo 260 Silver)|Qualcomm SDM665 Snapdragon 665 (11 nm)|Adreno 610|Android 10, Funtouch 10|HDR|16 MP, f/2.0, (wide), 1/3.06" 1.0m|1080p@30fps|128GB storage, microSDXC|',
       '//www.lazada.com.ph/products/with-free-bluetooth-earphone-huge-benefits-vivo-y51a-original-genuine-mobile-phone-50-inch-screen-dual-cameras-storage-capacity-2gb16gb-i1121926928.html|vivo|188g, 8.4mm thickness|Android|Y51a|Released 2021, January 23|18W wired, 70% in 67 min (advertised)|5000 mAh|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|IPS LCD|2021|Available. Released 2021, January 23|LED flash, HDR, panorama|48 MP, f/1.8, (wide), 1/2.0", 0.8m, PDAF\n8 MP, f/2.2, 120, (ultrawide), 1/4.0", 1.12m\n2 MP, f/2.4, (macro)|4K@30fps, 1080p@30fps, gyro-EIS|microSDXC (dedicated slot)|Titanium Sapphire, Crystal Symphony|V2031|About 200 EUR|0.87 W/kg (head)   0.39 W/kg (body)   |Octa-core (4x2.0 GHz Kryo 260 Gold & 4x1.8 GHz Kryo 260 Silver)|Qualcomm SM6115 Snapdragon 662 (11 nm)|Adreno 610|Android 11, upgradable to Android 12, Funtouch 12|HDR|16 MP, f/2.0, (wide), 1/3.06" 1.0m|1080p@30fps|128GB storage, microSDXC|',
       '//www.lazada.com.ph/products/in-1-year-warrantyvivo-y55-332gb-cellphone-original-brand-new-cheap-phone-mobile-phone-unlock-android-55inch-hd-camera-5mp-13mp-local-fast-delivery-shop-i4254499947.html|vivo|182g, 8.4mm thickness|Android|Y55|Released 2022, July 02|44W wired, 1-50% in 27 min (advertised)|5000 mAh|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|Schott Xensation glass|AMOLED|2022|Available. Released 2022, July 02|LED flash, HDR, panorama|50 MP, f/1.8, (wide), 1/2.76", 0.64m, PDAF\n2 MP, f/2.4, (macro)\n2 MP, f/2.4, (depth)|1080p@30fps, gyro-EIS|microSDXC (dedicated slot)|Midnight Galaxy, Ice Dawn|Unknown|About 250 EUR|Octa-core (4x2.4 GHz Kryo 265 Gold & 4x1.9 GHz Kryo 265 Silver)|Qualcomm SM6225 Snapdragon 680 4G (6 nm)|Adreno 610|Android 12, Funtouch 12|16 MP, f/2.0, (wide)|1080p@30fps|128GB storage, microSDXC|',
       '//www.lazada.com.ph/products/vivo-y73s-5g-smartphone-2023-new-original-644-amoled-4k-fhd-screen-12512gb-48mp-ai-triple-camera-android-mobile-phone-18w-fast-charging-gaming-phone-cellphone-i4236035815.html|vivo|171.3g, 7.8mm thickness|Android|Y73s|Released 2020, October 16|18W wired|4100 mAh|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|AMOLED, HDR10|2020|Available. Released 2020, October 16|LED flash, HDR, panorama|48 MP, f/1.8, 26mm (wide), 1/2.0", 0.8m, PDAF\n8 MP, f/2.2, 16mm, 120 (ultrawide), 1/4.0", 1.12m\n2 MP, f/2.4, (depth)|4K@30fps, 1080p@30fps; gyro-EIS|No|UFS 2.1|Black, Silver|V2031A|About 280 EUR|Octa-core (2x2.0 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)|Mediatek Dimensity 720 (7 nm)|Mali-G57 MC3|Android 10, Funtouch 10.5|HDR|16 MP, f/2.0, (wide)|1080p@30fps|128GB/256GB storage, no card slot|',
       '//www.lazada.com.ph/products/vivo-y76-5g-8gb128gb-i3160015695.html|vivo|175g, 7.8mm thickness|Android|Y76 5G|Released 2021, November 23|44W wired, 70% in 32 min (advertised)|4100 mAh|Hybrid Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS, GLONASS, GALILEO, BDS, QZSS|Radio|USB Type-C, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|IPS LCD, 460 nits (typ)|2021|Available. Released 2021, November 23|LED flash, HDR, panorama|50 MP, f/1.8, 26mm (wide), PDAF\n2 MP, f/2.4, (macro)\n2 MP, f/2.4, (depth)|1080p@30fps, gyro-EIS|microSDXC (uses shared SIM slot)|Cosmic Aurora, Midnight Space|V2124|199.00|Octa-core (2x2.2 GHz Cortex-A76 & 6x2.0 GHz Cortex-A55)|Mediatek Dimensity 700 (7 nm)|Mali-G57 MC2|Android 11, Funtouch 12|16 MP, f/2.0, (wide)|1080p@30fps|128GB storage, microSDXC|',
       '//www.lazada.com.ph/products/vivo-y78-plus-mobile-phone-678-inch-amoled-snapdragon-695-octa-core-44w-superflash-charge-50m-triple-camera-i3825375115.html|vivo|177g, 7.9mm thickness|Android|Y78+|Released 2023, April 26|44W wired|5000 mAh|Dual SIM (Nano-SIM, dual stand-by)|Bluetooth|NFC|GPS (L1), GLONASS (G1), BDS (B1I+B1c), GALILEO (E1), QZSS (L1)|Radio|USB Type-C 2.0, OTG|Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct|AMOLED, 120Hz, 1300 nits (peak)|2023|Available. Released 2023, April 26|50 MP, f/1.8, (wide), PDAF, OIS\n2 MP, f/2.4, (depth)|LED flash, HDR, panorama|1080p@30fps|No|UFS 2.2|Black, Blue, Gold|V2271A|About 210 EUR|Octa-core (2x2.2 GHz Kryo 660 Gold & 6x1.7 GHz Kryo 660 Silver)|Qualcomm SM6375 Snapdragon 695 5G (6 nm)|Adreno 619|Android 13, OriginOS 3|8 MP, f/2.0, (wide)|1080p@30fps|128GB/256GB storage, no card slot|'
        ]

}

# Convert data to DataFrame
df = pd.DataFrame(data)

# TF-IDF Vectorization
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['Specifications'])


# Function to recommend phones based on similarity to given specifications
def recommend(specs, df=df):
    # Transform the input specs using TF-IDF vectorizer
    specs_vectorized = tfidf.transform([specs])
    # Calculate similarity scores between input specs and all phones
    sim_scores = cosine_similarity(specs_vectorized, tfidf_matrix)
    # Get indices of phones sorted by similarity scores
    phone_indices = sim_scores.argsort()[0][::-1]

    # Return recommended phones
    return df['Phone'].iloc[phone_indices]

# Example: Recommend phones similar to given specifications
input_specs = '5g'  # Example specifications
print(recommend('iphone 2023'))  # Example usage of the recommend function
# Out:
# 19    vivo Y3t Pro Max 5G
# 10               vivo Y36
# 11            vivo Y36 5G
# 17        vivo Y3t Pro 5G
# 3               iPhone 12
# 4          iPhone 12 Mini
# 0               iPhone 11
# 5           iPhone 12 Pro
# 7               iPhone 13
# 8          iPhone 13 Mini
# 1           iPhone 11 Pro
# 9           iPhone 13 Pro
# 6       iPhone 12 Pro Max
# 2       iPhone 11 Pro Max
# 12       vivo Y3 Standard
# 13               vivo Y3s
# 14               vivo Y3t
# 18       vivo Y3t Pro Max
# 15            vivo Y3t 5G
# 16           vivo Y3t Pro
# Name: Phone, dtype: object

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Sample numerical data (2 samples, 3 numerical features each)
data = np.array([[1, 2, 3], [4, 5, 6]])

# Normalize the data
normalized_data = data / np.linalg.norm(data, axis=1, keepdims=True)

# Initialize and fit TfidfTransformer
tfidf_transformer = TfidfTransformer()
tfidf_transformer.fit(normalized_data)

# Transform data to TF-IDF representation
tfidf_data = tfidf_transformer.transform(normalized_data)

# Calculate cosine similarity
similarities = cosine_similarity(tfidf_data)

# Find nearest neighbor
nearest_neighbor_index = np.argmax(similarities)

print("Nearest neighbor index:", nearest_neighbor_index)
# Out:
# Nearest neighbor index: 3

# %%
from sklearn.neighbors import NearestNeighbors


# combine the non numerical data into another dataframe
# concatenate the strings


# remove non utf-8 characters
def recommend(
        specs,
        n=20,
        k_nearest=10,
        **kwargs):
    
    tfidf = TfidfVectorizer(stop_words='english')
    X = tfidf.fit_transform(clean_data['details'].str.replace(r'[^a-zA-Z0-9_]', ' ', regex=True))
    # Transform the input specs using TF-IDF vectorizer
    specs_vectorized = tfidf.transform([specs])
    
    for k, v in kwargs.items():
        if k in clean_data.columns:
            X = hstack((X, tfidf.fit_transform(clean_data[k].astype(str).str.replace(r'[^a-zA-Z0-9_]', ' ', regex=True))))
            specs_vectorized = hstack((specs_vectorized, tfidf.transform([v])))
    
    # Use k-nearest neighbors algorithm
    nn = NearestNeighbors(n_neighbors=k_nearest)
    nn.fit(X)
    _, indices = nn.kneighbors(specs_vectorized)
    
    # Return recommended phones
    return clean_data.iloc[indices[0]].head(n)


# get the recommended phone
recommend('', brand='samsung', colors='purple', price_min='10000', k_nearest=10)[['brand', 'model', 'colors', 'price_min', 'price_max', 'release']]
